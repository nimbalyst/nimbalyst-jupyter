# %% [markdown]
# # Demo notebook
# Loads a dataset and prints some output.

# %%
import json
print(json.dumps({"hello": "world"}))
# Out:
# aaaaaaaaaa
# bbbbbbbbbb
# cccccccccc
# dddddddddd
# eeeeeeeeee
# ffffffffff
# gggggggggg
# hhhhhhhhhh
# iiiiiiiiii
# jjjjjjjjjj

# %%
float('oops')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 float('oops')
# ValueError: could not convert string to float: 'oops'
